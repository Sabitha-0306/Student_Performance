# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/student_performance_dataset.csv')

# %%
df.head()
# Out:
#    student_id  age  gender   city_type  study_hours_per_day  \
# 0           0   21  Female  Semi-Urban                  3.2
# 1           1   19  Female  Semi-Urban                  3.9
# 2           2   16  Female       Urban                  4.3
# 3           3   19    Male  Semi-Urban                  5.3
# 4           4   17  Female       Urban                  4.1
#
#    deep_work_sessions  assignment_completion_rate  attendance_percentage  \
# 0                   7                         100                     70
# 1                   2                          46                     70
# 2                   7                          54                     57
# 3                   1                          78                     90
# 4                   3                         100                     81
#
#    social_media_hours  doomscrolling_before_sleep  ...  family_support  \
# 0                 3.8                           0  ...              10
# ...

# %%
df.shape
# Out:
# (3000, 32)

# %%
df.tail()
# Out:
#       student_id  age  gender   city_type  study_hours_per_day  \
# 2995        2995   22  Female       Rural                  2.4
# 2996        2996   19  Female       Urban                  5.2
# 2997        2997   23  Female       Rural                  5.9
# 2998        2998   17    Male       Urban                  3.9
# 2999        2999   16  Female  Semi-Urban                  5.8
#
#       deep_work_sessions  assignment_completion_rate  attendance_percentage  \
# 2995                   0                          40                     83
# 2996                   7                          94                    100
# 2997                   2                          41                     86
# 2998                   1                          92                     96
# 2999                   0                          84                    100
#
#       social_media_hours  doomscrolling_before_sleep  ...  family_support  \
# ...

# %%
df.isnull().count()
# Out:
# student_id                     3000
# age                            3000
# gender                         3000
# city_type                      3000
# study_hours_per_day            3000
# deep_work_sessions             3000
# assignment_completion_rate     3000
# attendance_percentage          3000
# social_media_hours             3000
# doomscrolling_before_sleep     3000
# notification_distractions      3000
# ai_tool_usage_hours            3000
# gaming_hours                   3000
# stress_level                   3000
# motivation_level               3000
# focus_score                    3000
# procrastination_index          3000
# mental_state                   3000
# sleep_hours                    3000
# caffeine_intake                3000
# physical_activity_hours        3000
# internet_quality               3000
# family_support                 3000
# financial_stress               3000
# learning_style                 3000
# career_goal                    3000
# ...

# %%
df.dropna()
# Out:
#       student_id  age  gender   city_type  study_hours_per_day  \
# 0              0   21  Female  Semi-Urban                  3.2
# 1              1   19  Female  Semi-Urban                  3.9
# 2              2   16  Female       Urban                  4.3
# 3              3   19    Male  Semi-Urban                  5.3
# 4              4   17  Female       Urban                  4.1
# ...          ...  ...     ...         ...                  ...
# 2995        2995   22  Female       Rural                  2.4
# 2996        2996   19  Female       Urban                  5.2
# 2997        2997   23  Female       Rural                  5.9
# 2998        2998   17    Male       Urban                  3.9
# 2999        2999   16  Female  Semi-Urban                  5.8
#
#       deep_work_sessions  assignment_completion_rate  attendance_percentage  \
# 0                      7                         100                     70
# ...

# %%
df['assignment_completion_rate'].max()
# Out:
# 100

# %%
df['family_support'].value_counts()
# Out:
# family_support
# 6     322
# 4     318
# 1     312
# 3     312
# 5     299
# 8     299
# 10    296
# 7     285
# 9     285
# 2     272
# Name: count, dtype: int64

# %%
most = df['family_support'].mode()
df['family_support'].fillna(most, inplace=True)

# %%
df.describe()
# Out:
#         student_id          age  study_hours_per_day  deep_work_sessions  \
# count  3000.000000  3000.000000          3000.000000         3000.000000
# mean   1499.500000    19.030333             3.988767            3.511667
# std     866.169729     2.553217             1.503377            2.297743
# min       0.000000    15.000000             0.500000            0.000000
# 25%     749.750000    17.000000             2.900000            1.000000
# 50%    1499.500000    19.000000             4.000000            4.000000
# 75%    2249.250000    21.000000             5.000000            6.000000
# max    2999.000000    23.000000             8.800000            7.000000
#
#        assignment_completion_rate  attendance_percentage  social_media_hours  \
# count                 3000.000000            3000.000000         2940.000000
# mean                    69.926333              74.558000            2.949422
# std                     17.562794              14.473048            1.510306
# ...

# %%
sns.barplot(x='motivation_level',y='stress_level',data = df)
plt.show()

# %%
sns.lineplot(x='motivation_level',y='stress_level',data = df)
plt.show()

# %%
sns.histplot(x='focus_score',data =df)
plt.show()

# %%
df = df.drop(['age','gender','productivity_after_midnight','burnout_risk','city_type','doomscrolling_before_sleep'],axis = 1)

# %%
df.head()
# Out:
#    student_id  study_hours_per_day  deep_work_sessions  \
# 0           0                  3.2                   7
# 1           1                  3.9                   2
# 2           2                  4.3                   7
# 3           3                  5.3                   1
# 4           4                  4.1                   3
#
#    assignment_completion_rate  attendance_percentage  social_media_hours  \
# 0                         100                     70                 3.8
# 1                          46                     70                 2.6
# 2                          54                     57                 4.3
# 3                          78                     90                 1.7
# 4                         100                     81                 2.6
#
#    notification_distractions  ai_tool_usage_hours  gaming_hours  stress_level  \
# 0                        107                  0.6           1.8             8
# ...

# %%
data = pd.get_dummies(df,dtype = int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   student_id                   3000 non-null   int64
#  1   study_hours_per_day          3000 non-null   float64
#  2   deep_work_sessions           3000 non-null   int64
#  3   assignment_completion_rate   3000 non-null   int64
#  4   attendance_percentage        3000 non-null   int64
#  5   social_media_hours           2940 non-null   float64
#  6   notification_distractions    3000 non-null   int64
#  7   ai_tool_usage_hours          3000 non-null   float64
#  8   gaming_hours                 3000 non-null   float64
#  9   stress_level                 3000 non-null   int64
#  10  motivation_level             3000 non-null   int64
#  11  focus_score                  2940 non-null   float64
#  12  procrastination_index        3000 non-null   int64
# ...

# %%
x = df.drop('final_exam_score',axis = 1)
y = df['final_exam_score']

# %%
x.head()
y.head()
# Out:
# 0    32
# 1    59
# 2    34
# 3    60
# 4    77
# Name: final_exam_score, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
list(data)
# Out:
# ['student_id',
#  'study_hours_per_day',
#  'deep_work_sessions',
#  'assignment_completion_rate',
#  'attendance_percentage',
#  'social_media_hours',
#  'notification_distractions',
#  'ai_tool_usage_hours',
#  'gaming_hours',
#  'stress_level',
#  'motivation_level',
#  'focus_score',
#  'procrastination_index',
#  'sleep_hours',
#  'caffeine_intake',
#  'physical_activity_hours',
#  'internet_quality',
#  'family_support',
#  'financial_stress',
#  'revision_efficiency',
#  'consistency_score',
#  'final_exam_score',
#  'mental_state_Balanced',
#  'mental_state_Burnout',
#  'mental_state_Distracted',
#  'mental_state_Focused',
#  'learning_style_Audio',
#  'learning_style_Practical',
#  'learning_style_Reading',
#  'learning_style_Visual',
#  'career_goal_Arts',
#  'career_goal_Business',
#  'career_goal_Engineering',
#  'career_goal_Medical',
#  'career_goal_Research',
#  'performance_category_High',
#  'performance_category_Low',
#  'performance_category_Medium']
